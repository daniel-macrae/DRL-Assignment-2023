# %%
import os
#os.environ[ 'LD_LIBRARY_PATH'] = '$LD_LIBRARY_PATH:/home/daniel/.mujoco/mujoco210/bin'
#import mujoco_py

#export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/home/daniel/.mujoco/mujoco210/bin
#export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:/usr/lib/nvidia

import gymnasium as gym


print("hi")


env = gym.make("BipedalWalker-v3", render_mode = 'rgb_array')
env.reset()

out = env.step([1,2,3,4])
print(out)
# Out:
# hi
# (array([-0.01822654, -0.06589933, -0.01728051,  0.0281975 , -0.23366742,
#         0.192786  ,  1.4530098 ,  0.8343455 ,  1.        , -0.33829963,
#        -0.27289432,  1.7078757 ,  0.99152964,  1.        ,  0.45705283,
#         0.46224335,  0.4784208 ,  0.50758433,  0.5537782 ,  0.62465465,
#         0.7352727 ,  0.918568  ,  1.        ,  1.        ], dtype=float32), -0.1454887090139091, False, False, {})
# /home/daniel/miniconda3/envs/DRLenv/lib/python3.10/site-packages/gymnasium/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %%
import matplotlib.pyplot as plt

out = env.step([1,2,3,4])
print(out)
plt.imshow(env.render())
plt.show()
# Out:
# (array([-1.0365709e+00, -1.3726305e-03,  9.5717534e-03, -2.7798890e-04,
#         1.1336093e+00,  4.2207725e-04,  9.3110108e-01,  1.5038438e-04,
#         1.0000000e+00,  1.1267270e+00, -7.7253208e-06,  9.3489712e-01,
#        -6.7214794e-05,  0.0000000e+00,  4.5362943e-01,  4.5878106e-01,
#         4.7483733e-01,  5.0378245e-01,  5.4963034e-01,  6.1997586e-01,
#         7.2976536e-01,  9.1168779e-01,  1.0000000e+00,  1.0000000e+00],
#       dtype=float32), -0.10856426906585694, False, False, {})

# %%
(observation, reward, something1, something2, _) = env.step([1,2,3,4])

# %%
import matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# plots average rewards over the episodes, in a way that updates the plot during the training loop
def plotEnv(env, show_result=False):
    plt.figure(1)
    if show_result:
        plt.title('Result')
    else:
        plt.clf()
        plt.title('Training...')
    #plt.ylabel('Average reward (over 10 episodes)')
    #plt.xlabel('Episode number')
    plt.imshow(env)
    plt.axis('off')
    # Take 100 episode averages and plot them too

    plt.pause(0.0001)  # pause a bit so that plots are updated
    if is_ipython:
        if not show_result:
            display.display(plt.gcf())
            display.clear_output(wait=True)
        else:
            display.display(plt.gcf())

# %%
observation = env.reset()
done = False

while not done:
    

    action = env.action_space.sample()  # Replace with your own action selection logic
    (observation, reward, done, something2, _) = env.step(action)
    render = env.render()
    plotEnv(render, done)

    

env.close()

# %%
import glfw
assert glfw.init()

# %%
import glfw3
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/daniel/Desktop/DeepRL/play1.ipynb Cell 2 in 1
# ----> <a href='vscode-notebook-cell:/home/daniel/Desktop/DeepRL/play1.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> import glfw3
#
# ModuleNotFoundError: No module named 'glfw3'

# %%
import mujoco_py
# Out:
# Import error. Trying to rebuild mujoco_py.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/daniel/Desktop/DeepRL/play1.ipynb Cell 2 in 1
# ----> <a href='vscode-notebook-cell:/home/daniel/Desktop/DeepRL/play1.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> import mujoco_py
#
# File ~/miniconda3/envs/DRLenv/lib/python3.10/site-packages/mujoco_py/__init__.py:15
#      12     os.environ["LD_LIBRARY_PATH"] = os.path.join(mujoco_py.__path__[0], "binaries", "windows", "mujoco210", "bin")
#      14 #!/usr/bin/env python
# ---> 15 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#      16 from mujoco_py.generated import const
#      17 from mujoco_py.mjrenderpool import MjRenderPool
#
# File ~/miniconda3/envs/DRLenv/lib/python3.10/site-packages/mujoco_py/builder.py:499
#     495     return module.lib.__fun
#     498 mujoco_path = discover_mujoco()
# ...

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 5.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.3/300.3 kB 5.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.7 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#   Using cached fonttools-4.39.4-py3-none-any.whl (1.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gymnasium[box2d]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 5.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 5.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 5.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [16 lines of output]
#       Using setuptools (version 66.0.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.linux-x86_64-cpython-310
#       creating build/lib.linux-x86_64-cpython-310/Box2D
#       copying library/Box2D/__init__.py -> build/lib.linux-x86_64-cpython-310/Box2D
#       copying library/Box2D/Box2D.py -> build/lib.linux-x86_64-cpython-310/Box2D
#       creating build/lib.linux-x86_64-cpython-310/Box2D/b2
# ...

# %%
import glfw
assert glfw.init()
# Out:
# xkbcommon: ERROR: failed to add default include path /home/daniel/miniconda3/envs/DRLenv/share/X11/xkb
# ---------------------------------------------------------------------------
# GLFWError                                 Traceback (most recent call last)
# /home/daniel/Desktop/DeepRL/play1.ipynb Cell 2 in 2
#       <a href='vscode-notebook-cell:/home/daniel/Desktop/DeepRL/play1.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> import glfw
# ----> <a href='vscode-notebook-cell:/home/daniel/Desktop/DeepRL/play1.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> assert glfw.init()
#
# File ~/miniconda3/envs/DRLenv/lib/python3.10/site-packages/glfw/__init__.py:726, in init()
#     719 """
#     720 Initializes the GLFW library.
#     721
#     722 Wrapper for:
#     723     int glfwInit(void);
#     724 """
#     725 cwd = _getcwd()
# --> 726 res = _glfw.glfwInit()
#     727 os.chdir(cwd)
#     728 return res
#
# ...

# %%
print('hi')
# Out:
# hi

# %%
pip install Cython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy.stats as stats

print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/daniel/Desktop/DeepRL/play1.ipynb Cell 10 in 3
#       <a href='vscode-notebook-cell:/home/daniel/Desktop/DeepRL/play1.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> import scipy.stats as stats
# ----> <a href='vscode-notebook-cell:/home/daniel/Desktop/DeepRL/play1.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> print(scipy -V)
#
# NameError: name 'scipy' is not defined

# %%
import scipy

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 5.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 5.4 MB/s eta 0:00:00a 0:00:01
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 5.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 4.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
#import mujoco_py
import matplotlib.pyplot as plt

def render_mujoco(env):
    observation = env.reset()
    done = False

    #while not done:
    env_screen = env.render()

    import matplotlib.pyplot as plt 
    plt.imshow(env_screen)
    plt.show()

    action = env.action_space.sample()  # Replace with your own action selection logic
    observation = env.step(action)

    env.close()

# Create the MuJoCo environment
#import gym
env = gym.make('MountainCar-v0', render_mode = 'rgb_array')

# Render and run the environment
render_mujoco(env)

# %%
import gymnasium as gym
env = gym.make('CartPole-v0')
env.reset()

for i in range(1):
    env.step(env.action_space.sample())
    #sleep(0.5)
    env.render()
# Out:
# /home/daniel/miniconda3/envs/DRLenv/lib/python3.11/site-packages/gymnasium/envs/classic_control/cartpole.py:215: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(

# %%
from gymnasium import wrappers
i#mport matplotlib.pyplot as plt


env = gym.make('CartPole-v0')
#env = gym.make("LunarLander-v2")#, render_mode="human")
env.action_space.seed(42)

observation, info = env.reset(seed=42, return_info=True)

for _ in range(1000):
    observation, reward, done, info = env.step(env.action_space.sample())

    if done:
        observation, info = env.reset(return_info=True)
        
    clear_output(wait=True)
    #plt.imshow( env.render(mode='rgb_array') )
    #plt.show()

env.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 from gymnasium import wrappers
# ----> 2 import matplotlib.pyplot as plt
#       5 env = gym.make('CartPole-v0')
#       6 #env = gym.make("LunarLander-v2")#, render_mode="human")
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
env.render_mode('rgb_array')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 env.render_mode('rgb_array')
#
# TypeError: 'NoneType' object is not callable

# %%
env.reset()
# Out:
# (array([ 0.7800178 ,  0.99616494,  0.07657441, -0.03470584, -0.02423379,
#         -0.0278665 , -0.09023004,  0.01807623, -0.06910822,  0.08185229,
#          0.02887662,  0.04007045, -0.0428855 ,  0.14414439,  0.03211963,
#         -0.01465166,  0.10508191,  0.10875025,  0.07020225,  0.02287817,
#         -0.03015075,  0.0130643 ,  0.06574815,  0.14167936, -0.0380514 ,
#         -0.26325366, -0.0206472 ]),
#  {})

# %%
env.step((1,2,3,4,5,6,7,8))
# Out:
# (array([ 0.82470792,  0.99712949,  0.05963591, -0.041405  ,  0.02149345,
#          0.12572283,  0.50021997,  0.09317686, -0.38476288,  0.16660551,
#         -0.37150504,  0.18711562,  0.50223956,  0.11532252, -0.1002463 ,
#          0.24576075,  0.0551623 , -1.80333642, -4.25993972,  7.48192018,
#         14.21716869,  7.40187198, -4.88541952,  7.33733367, -5.73021644,
#          7.26700766, 14.19977166]),
#  -100.93786436904675,
#  False,
#  False,
#  {'reward_forward': 0.062135630953254195,
#   'reward_ctrl': -102.0,
#   'reward_survive': 1.0,
#   'x_position': 0.08708442962025702,
#   'y_position': 0.04657443389543998,
#   'distance_from_origin': 0.09875664926963756,
#   'x_velocity': 0.062135630953254195,
#   'y_velocity': -0.10996906814561877,
#   'forward_reward': 0.062135630953254195})

# %%
env.render()
# Out:
# xkbcommon: ERROR: failed to add default include path /home/daniel/miniconda3/envs/DRLenv/share/X11/xkb
# /home/daniel/miniconda3/envs/DRLenv/lib/python3.11/site-packages/glfw/__init__.py:916: GLFWError: (65544) b'Wayland: Failed to initialize xkb context'
#   warnings.warn(message, GLFWError)
# /home/daniel/miniconda3/envs/DRLenv/lib/python3.11/site-packages/glfw/__init__.py:916: GLFWError: (65537) b'The GLFW library is not initialized'
#   warnings.warn(message, GLFWError)
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 env.render()
#
# File ~/miniconda3/envs/DRLenv/lib/python3.11/site-packages/gymnasium/core.py:418, in Wrapper.render(self)
#     416 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     417     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# ...

# %%
import gymnasium as gym
from gymnasium.wrappers import HumanRendering
import pygame
import mujoco_py
import os

#MUJOCO_PY_MUJOCO_PATH = "/.mujoco/mujoco210"

mj_path = mujoco_py.utils.discover_mujoco()
xml_path = os.path.join(mj_path, 'model', 'humanoid.xml')
model = mujoco_py.load_model_from_path(xml_path)
sim = mujoco_py.MjSim(model)


env = gym.make("Ant-v4", render_mode = 'rgb_array')
env.reset()

#env.render()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 from gymnasium.wrappers import HumanRendering
#       3 import pygame
# ----> 4 import mujoco_py
#       5 import os
#       7 #MUJOCO_PY_MUJOCO_PATH = "/.mujoco/mujoco210"
#
# File ~/miniconda3/envs/DRLenv/lib/python3.11/site-packages/mujoco_py/__init__.py:2
#       1 #!/usr/bin/env python
# ----> 2 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       3 from mujoco_py.generated import const
#       4 from mujoco_py.mjrenderpool import MjRenderPool
#
# File ~/miniconda3/envs/DRLenv/lib/python3.11/site-packages/mujoco_py/builder.py:504
#     500     return module.lib.__fun
#     503 mujoco_path = discover_mujoco()
# --> 504 cymj = load_cython_ext(mujoco_path)
#     507 # Trick to expose all mj* functions from mujoco in mujoco_py.*
#     508 class dict2(object):
# ...

# %%
import mujoco_py



viewer = mujoco_py.MjViewer(env)
image = env.render(width=300, height = 300, camera_name='cam0', depth=False)
# Out:
# You appear to be missing MuJoCo.  We expected to find the file here: /home/daniel/.mujoco/mujoco210
#
# This package only provides python bindings, the library must be installed separately.
#
# Please follow the instructions on the README to install MuJoCo
#
#     https://github.com/openai/mujoco-py#install-mujoco
#
# Which can be downloaded from the website
#
#     https://www.roboti.us/index.html
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mujoco_py
#       5 viewer = mujoco_py.MjViewer(env)
#       6 image = env.render(width=300, height = 300, camera_name='cam0', depth=False)
#
# File ~/miniconda3/envs/DRLenv/lib/python3.11/site-packages/mujoco_py/__init__.py:2
#       1 #!/usr/bin/env python
# ----> 2 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
# ...

# %%
import mujoco_py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import mujoco_py
#
# ModuleNotFoundError: No module named 'mujoco_py'

# %%
pip install libegl-dev libegl
# Out:
# ERROR: Could not find a version that satisfies the requirement libegl-dev (from versions: none)
# ERROR: No matching distribution found for libegl-dev
# Note: you may need to restart the kernel to use updated packages.
