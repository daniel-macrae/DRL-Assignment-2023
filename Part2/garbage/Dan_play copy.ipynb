# %%
pip install gymnasium[box2d]
# Out:
# ...
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached pygame-2.1.3-cp310-cp310-win_amd64.whl (10.4 MB)
# ...
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# ...
#   Running setup.py install for box2d-py: started
#   Running setup.py install for box2d-py: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       Using setuptools (version 65.6.3).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-310
#       creating build\lib.win-amd64-cpython-310\Box2D
#       copying library\Box2D\Box2D.py -> build\lib.win-amd64-cpython-310\Box2D
# ...

# %%
print("1")
# Out:
# 1

# %%
import mujoco

env = mujoco

# %%
pip uninstall mujoco

# %%
pip install gym[mujoco]
# Out:
# ...
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached numpy-1.24.3-cp310-cp310-win_amd64.whl (14.8 MB)
# ...
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# ...
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# ...
#   Using cached imageio-2.29.0-py3-none-any.whl (3.4 MB)
# ...
#   Using cached mujoco-2.2.0-cp310-cp310-win_amd64.whl (2.8 MB)
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# ...
#   Using cached PyOpenGL-3.1.7-py3-none-any.whl (2.4 MB)
# ...
#   Using cached glfw-2.5.9-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-win_amd64.whl (493 kB)
# ...
#   Using cached Pillow-9.5.0-cp310-cp310-win_amd64.whl (2.5 MB)
# ...

# %%
pip install mujoco-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !conda list
# Out:
# # packages in environment at C:\Users\danie\miniconda3\envs\DRLenv:
# #
# # Name                    Version                   Build  Channel
# absl-py                   1.4.0                    pypi_0    pypi
# asttokens                 2.0.5              pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# blas                      1.0                         mkl
# bottleneck                1.3.5           py310h9128911_0
# brotli                    1.0.9                h2bbff1b_7
# brotli-bin                1.0.9                h2bbff1b_7
# brotlipy                  0.7.0           py310h2bbff1b_1002
# bzip2                     1.0.8                he774522_0
# ca-certificates           2023.01.10           haa95532_0
# certifi                   2023.5.7        py310haa95532_0
# cffi                      1.15.1          py310h2bbff1b_3
# charset-normalizer        2.0.4              pyhd3eb1b0_0
# ...

# %%
pip list
# Out:
# Package              Version
# -------------------- --------
# absl-py              1.4.0
# asttokens            2.0.5
# backcall             0.2.0
# Bottleneck           1.3.5
# brotlipy             0.7.0
# certifi              2023.5.7
# cffi                 1.15.1
# charset-normalizer   2.0.4
# cloudpickle          2.2.1
# colorama             0.4.6
# comm                 0.1.2
# contourpy            1.0.5
# cryptography         39.0.1
# cycler               0.11.0
# Cython               0.29.35
# debugpy              1.5.1
# decorator            5.1.1
# executing            0.8.3
# Farama-Notifications 0.0.4
# fasteners            0.18
# filelock             3.9.0
# fonttools            4.25.0
# glfw                 2.5.9
# gym                  0.26.2
# gym-notices          0.0.8
# gymnasium            0.28.1
# idna                 3.4
# imageio              2.29.0
# ipykernel            6.19.2
# ipython              8.12.0
# jax-jumpy            1.0.0
# ...

# %%
conda uninstall mujoco_py
# Out:
# ...
# Solving environment: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are missing from the target environment:
#   - mujoco_py

# %%
import gym as gym

env = gym.make("Ant-v4", render_mode = 'rgb_array')

env.reset()
# Out:
# (array([ 0.67877591,  0.98965529, -0.08140923,  0.09176319,  0.07439401,
#         -0.00187786, -0.02903505,  0.05463716, -0.05654982, -0.09308017,
#         -0.03721081, -0.05162648,  0.01860247,  0.07181149, -0.01596274,
#          0.01683578,  0.04839548, -0.00305874,  0.14530852,  0.02498809,
#         -0.06734307,  0.03081398, -0.10438805, -0.01933812, -0.08276749,
#         -0.08155769,  0.16990518]),
#  {})

# %%
img = env.render()

import matplotlib.pyplot as plt

plt.imshow(img)
plt.show()

# %%
pip install gym
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mujoco
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 import mujoco_py
#
# ModuleNotFoundError: No module named 'mujoco_py'

# %%
import mujoco_py
# Out:
# You appear to be missing MuJoCo.  We expected to find the file here: C:\Users\danie\.mujoco\mujoco210
#
# This package only provides python bindings, the library must be installed separately.
#
# Please follow the instructions on the README to install MuJoCo
#
#     https://github.com/openai/mujoco-py#install-mujoco
#
# Which can be downloaded from the website
#
#     https://www.roboti.us/index.html
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import mujoco_py
#
# File c:\Users\danie\miniconda3\envs\DRLenv\lib\site-packages\mujoco_py\__init__.py:2
#       1 #!/usr/bin/env python
# ----> 2 from mujoco_py.builder import cymj, ignore_mujoco_warnings, functions, MujocoException
#       3 from mujoco_py.generated import const
#       4 from mujoco_py.mjrenderpool import MjRenderPool
#
# ...

# %%
state, reward, bool1, bool2, dictionary = env.step(action=(1,2,3,4,5,6,7,8))

# %%
import matplotlib.pyplot as plt

plt.imshow(state)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.imshow(state)
#
# File c:\Users\danie\miniconda3\envs\DRLenv\lib\site-packages\matplotlib\pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
# ...

# %%
env.render()
# Out:
# c:\Users\danie\miniconda3\envs\DRLenv\lib\site-packages\gym\envs\mujoco\mujoco_env.py:360: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("Ant-v4", render_mode="rgb_array")
#   gym.logger.warn(

# %%
import gymnasium as gym


env = gym.make("Breakout-v4", mode = 0, obs_type="grayscale")
env.observation_space
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import gymnasium as gym
#       4 env = gym.make("Breakout-v4", mode = 0, obs_type="grayscale")
#       5 env.observation_space
#
# ModuleNotFoundError: No module named 'gymnasium'

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import gymnasium as gym


env = gym.make("BreakoutNoFrameskip-v4", obs_type='grayscale')
env.observation_space
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import gymnasium as gym
#       4 env = gym.make("BreakoutNoFrameskip-v4", obs_type='grayscale')
#       5 env.observation_space
#
# ModuleNotFoundError: No module named 'gymnasium'

# %%
out = env.reset()

# %%
for idx in range(500):
    output = env.step(1)
    print(output[1:])
    #plt.imshow(output[0], cmap='gray')
    #plt.show()
# Out:
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 101, 'frame_number': 101})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 102, 'frame_number': 102})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 103, 'frame_number': 103})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 104, 'frame_number': 104})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 105, 'frame_number': 105})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 106, 'frame_number': 106})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 107, 'frame_number': 107})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 108, 'frame_number': 108})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 109, 'frame_number': 109})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 110, 'frame_number': 110})
# (0.0, False, False, {'lives': 4, 'episode_frame_number': 111, 'frame_number': 111})
# ...

# %%
len(out)
# Out:
# 2

# %%
out[1]
# Out:
# {'lives': 5, 'episode_frame_number': 0, 'frame_number': 0}

# %%
frame = out[0]

import matplotlib.pyplot as plt

plt.imshow(frame)

# %%
pip install gym[accept-rom-license]
# Out:
# ...
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# ...
#      -------------------------------------- 434.7/434.7 kB 5.4 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446679 sha256=f47595e33f8cb26bea67fdc3c76f3aeb6f83d642fa8efef9a7ab5d1c9b33ebcb
#   Stored in directory: c:\users\danie\appdata\local\pip\cache\wheels\15\bf\10\6cc7f59132f476bea696c71f40adac1f38459735f34c0fd76d
# Successfully built AutoROM.accept-rom-license
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gymnasium[atari]
# Out:
# ...
#      ------------------------------------- 952.4/952.4 kB 15.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
